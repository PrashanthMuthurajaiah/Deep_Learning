# %%
from IPython.display import Image
Image(filename='./images/CNN1.png')

# %%
Image(filename='./images/CNN2.png')

# %%
Image(filename='./images/CNN3.png')

# %%
Image(filename='./images/CNN4.png')

# %%
Image(filename='./images/CNN5.png')

# %%
Image(filename='./images/CNN6.png')

# %%
Image(filename='./images/CNN7.png')

# %% [markdown]
# Max pooling is little less sensitive to position. Because it takes the maximum in the window, without taking position into consideration.

# %%
Image(filename='./images/CNN8.png')

# %% [markdown]
# Normalization : Keep the math by breaking, by just tweaking each value of the values just a bit. This changes all the negative values to zero.

# %%
Image(filename='./images/CNN9.png')

# %% [markdown]
# Fully connected layers introduces votes to classify each class, the fully connected layers can also be stacked upon each other where one fullyconnected layer acts as an input to another fully connected layer
