# %%
from IPython.display import Image

# %%
Image(filename='./images/NN1.png')

# %% [markdown]
# Each Pixel becomes a input neuron (4 Input Neurons), where each input neuron is a assigned a number depending upon how bright or dark these individual pixels are.

# %%
Image(filename='./images/NN2.png')

# %% [markdown]
# Receptive field of a neuron : what value of input, that can make the value of this neuron as high as it can possibily be.

# %% [markdown]
# The first step in the neural network is all the values of input neurons are summed together and are multiplied by a initial weight

# %%
Image(filename='./images/NN3.png')

# %%
Image(filename='./images/NN4.png') # After initilializing weights to each input neuron, we can see an entirely 
# different value.

# %% [markdown]
# Notation : Black links are negative weights, white links are positive weights and no link suggest a 0 weight. Thickness of line is roughly proportional to the magnitude of the weight.

# %% [markdown]
# After the addition up of input neurons and weights this value is sent through a squashing function. For example here a sigmoid activation function which outputs the values bwteen 0 and 1. at some point of time even when the values are bigger that activation functions doesnt increase the value

# %%
Image(filename='./images/NN5.png') # Activation function not increasing its value after a certain limit

# %%
Image(filename='./images/NN6.png') # Neural networks receptive field becomes more complex

# %%
Image(filename='./images/NN7.png') # Neural networks receptive field becomes more complex

# %%
Image(filename='./images/NN8.png')
